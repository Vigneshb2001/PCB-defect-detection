# %% [markdown]
# Mounting Google Drive

# %%
from google.colab import drive

drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# Creating base directory

# %%
mkdir "/content/drive/MyDrive/PCB defect detection project"

# %%
cd "/content/drive/MyDrive/PCB defect detection project"
# Out:
# /content/gdrive/MyDrive/modified-yolov8

# %% [markdown]
# Installing libraries and dependencies

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.0/566.0 kB 18.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.1/203.1 kB 23.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# Downloading Dataset

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="CfYzsURnYfwsDACUmPwd")
project = rf.workspace("pcbdataset").project("pcb-defect-detection-9ewqw")
dataset = project.version(1).download("yolov8")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.2/56.2 kB 7.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.6 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9676 sha256=68932e5ea26ee144536ff0fa5bf651e7ed7a326103cae4980b42ccb43a49e630
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
# ...

# %% [markdown]
# Creating directory for training the model

# %%
mkdir "/content/gdrive/MyDrive/PCB defect detection project/Modified YOLOv8 with pretrained weights of YOLOv8n Adam optimizer and learning rate 0.001"

# %%
cd "/content/gdrive/MyDrive/PCB defect detection project/Modified YOLOv8 with pretrained weights of YOLOv8n Adam optimizer and learning rate 0.001"
# Out:
# /content/gdrive/MyDrive/PCB defect detection project/Modified YOLOv8 with pretrained weights of YOLOv8n Adam optimizer and learning rate 0.001

# %% [markdown]
# Defining the modified architecture of YOLOv8 in model.yaml file

# %%
# !touch model.yaml

# %% [markdown]
# Training the model

# %%
# !yolo detect train data="/content/drive/MyDrive/PCB defect detection project/pcb-defect-detection-1/data.yaml" \
model="/content/drive/MyDrive/PCB defect detection project/Modified YOLOv8 with pretrained weight of YOLOv8n Adam optimizer and learning rate 0.001/model.yaml" \
pretrained=yolov8n.pt epochs=100 imgsz=640 batch=32 device=0 workers=8 amp=False lr0=0.001 lrf=0.01 optimizer="Adam"
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.Conv                  [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.Conv                  [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.C2f                   [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.C2f                   [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
# ...

# %% [markdown]
# Validating the model

# %%
# !yolo detect val model="/content/gdrive/MyDrive/PCB defect detection project/Modified YOLOv8 with pretrained weights of YOLOv8n Adam optimizer and learning rate 0.001/runs/detect/train/weights/best.pt" \
data="/content/gdrive/MyDrive/PCB defect detection project/pcb-defect-detection-1/data.yaml" batch=1 imgsz=640 device=0
# Out:
# Ultralytics YOLOv8.0.93 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# model summary (fused): 186 layers, 3302882 parameters, 0 gradients, 8.3 GFLOPs
# ...
# 100% 755k/755k [00:00<00:00, 129MB/s]
# val: Scanning /content/gdrive/MyDrive/PCB defect detection project/pcb-defect-detection-1/valid/labels... 62 images, 0 backgrounds, 0 corrupt: 100% 62/62 [00:25<00:00,  2.39it/s]
# val: New cache created: /content/gdrive/MyDrive/PCB defect detection project/pcb-defect-detection-1/valid/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 62/62 [00:03<00:00, 20.01it/s]
#                    all         62        273      0.865      0.752      0.816      0.302
#           missing_hole         62         83      0.895      0.921       0.92      0.386
#             mouse_bite         62         47       0.83      0.745      0.815       0.35
# ...
