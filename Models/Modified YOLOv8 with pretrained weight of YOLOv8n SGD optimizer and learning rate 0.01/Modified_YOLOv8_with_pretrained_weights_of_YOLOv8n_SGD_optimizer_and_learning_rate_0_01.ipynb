# %% [markdown]
# Mounting Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Creating base directory

# %%
mkdir "/content/drive/MyDrive/PCB defect detection project"

# %%
cd "/content/drive/MyDrive/PCB defect detection project"
# Out:
# /content/drive/MyDrive/PCB defect detection project

# %% [markdown]
# Installing libraries and dependency

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 565.5/565.5 kB 30.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.1/203.1 kB 25.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# Downloading dataset

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="CfYzsURnYfwsDACUmPwd")
project = rf.workspace("pcbdataset").project("pcb-defect-detection-9ewqw")
dataset = project.version(1).download("yolov8")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.4 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9676 sha256=52469ace4fc0d65b026cc72f46505136241688086e2f746ae5ebb1d42fbd1532
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
# ...

# %% [markdown]
# Creating directory for training the model

# %%
mkdir "/content/drive/MyDrive/PCB defect detection project/Modified YOLOv8 with pretrained weight of YOLOv8n SGD optimizer and learning rate 0.01"

# %%
cd "/content/drive/MyDrive/PCB defect detection project/Modified YOLOv8 with pretrained weight of YOLOv8n SGD optimizer and learning rate 0.01"
# Out:
# /content/drive/MyDrive/PCB defect detection project/Modified YOLOv8 with pretrained weight of YOLOv8n SGD optimizer and learning rate 0.01

# %% [markdown]
# Defining the modified architecture of YOLOv8 in model.yaml file

# %%
# !touch model.yaml

# %% [markdown]
# Training the model

# %%
# !yolo detect train data="/content/drive/MyDrive/PCB defect detection project/pcb-defect-detection-1/data.yaml" \
model="/content/drive/MyDrive/PCB defect detection project/Modified YOLOv8 with pretrained weight of YOLOv8n SGD optimizer and learning rate 0.01/model.yaml" \
pretrained=yolov8n.pt epochs=100 imgsz=640 batch=32 device=0 workers=8 amp=False
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.Conv                  [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.Conv                  [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.C2f                   [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.C2f                   [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
# ...

# %% [markdown]
# Validating the model

# %%
# !yolo detect val model="/content/drive/MyDrive/PCB defect detection project/Modified YOLOv8 with pretrained weight of YOLOv8n SGD optimizer and learning rate 0.01/runs/detect/train/weights/best.pt" \
data="/content/drive/MyDrive/PCB defect detection project/pcb-defect-detection-1/data.yaml" batch=1 imgsz=640 device=0
# Out:
# Ultralytics YOLOv8.0.93 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# model summary (fused): 186 layers, 3302882 parameters, 0 gradients, 8.3 GFLOPs
# val: Scanning /content/drive/MyDrive/PCB defect detection project/pcb-defect-detection-1/valid/labels.cache... 62 images, 0 backgrounds, 0 corrupt: 100% 62/62 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 62/62 [00:01<00:00, 34.33it/s]
#                    all         62        273      0.786      0.667      0.776      0.291
#           missing_hole         62         83      0.758      0.795      0.865       0.35
#             mouse_bite         62         47      0.941      0.683      0.838      0.291
#           open_circuit         62         28      0.724      0.607      0.699      0.256
#                  short         62         35       0.81      0.729      0.838      0.353
# ...
