# %% [markdown]
# Mounting Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Create base directory

# %%
mkdir "/content/drive/MyDrive/PCB defect detection project"

# %%
cd "/content/drive/MyDrive/PCB defect detection project"
# Out:
# /content/drive/MyDrive/PCB defect detection project

# %% [markdown]
# Install libraries and dependencies

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 565.5/565.5 kB 34.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.1/203.1 kB 17.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# Downloading dataset

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="CfYzsURnYfwsDACUmPwd")
project = rf.workspace("pcbdataset").project("pcb-defect-detection-9ewqw")
dataset = project.version(1).download("yolov8")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 6.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 8.2 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9676 sha256=5d8817baff278bb9c915c4c8a1533dc43279a8cb706d756b439e00502f9dea96
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
# ...

# %% [markdown]
# Create a directory for training the model

# %%
mkdir "/content/drive/MyDrive/PCB defect detection project/Original YOLOv8n with Adam optimizer and learning rate 0.001"

# %%
cd "/content/drive/MyDrive/PCB defect detection project/Original YOLOv8n with Adam optimizer and learning rate 0.001"
# Out:
# /content/drive/MyDrive/PCB defect detection project/Original YOLOv8n with Adam optimizer and learning rate 0.001

# %% [markdown]
# Training the model

# %%
# !yolo detect train data="/content/drive/MyDrive/PCB defect detection project/pcb-defect-detection-1/data.yaml" model=yolov8n.pt epochs=100 imgsz=640 batch=32 device=0 workers=8 \
amp=False optimizer="Adam" lr0=0.001 lrf=0.01
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 82.9MB/s]
# Ultralytics YOLOv8.0.93 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# Validating the model

# %%
# !yolo detect val model="/content/drive/MyDrive/PCB defect detection project/Original YOLOv8n with Adam optimizer and learning rate 0.001/runs/detect/train/weights/best.pt" data="/content/drive/MyDrive/PCB defect detection project/pcb-defect-detection-1/data.yaml" batch=1 imgsz=640 device=0
# Out:
# Ultralytics YOLOv8.0.93 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006818 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/PCB defect detection project/pcb-defect-detection-1/valid/labels.cache... 62 images, 0 backgrounds, 0 corrupt: 100% 62/62 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 62/62 [00:01<00:00, 34.98it/s]
#                    all         62        273      0.802      0.717      0.796      0.308
#           missing_hole         62         83      0.826      0.798      0.892       0.35
#             mouse_bite         62         47      0.786      0.782      0.848       0.32
#           open_circuit         62         28      0.839      0.679      0.805      0.319
#                  short         62         35      0.849      0.806      0.862      0.363
# ...
